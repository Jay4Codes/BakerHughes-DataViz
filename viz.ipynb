# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import folium

# %%
site_df = pd.read_csv('./data/site_metadata-7fc535965d0c074cea0be6786fc9518e.csv')
site_df.head()
# Out:
#   CUSTOMER_NAME            PLANT_NAME   LATITUDE  LONGITUDE    ELEVATION  \
# 0        SPIFFY     SPIRITUAL-POLECAT  61.170356  42.874767   112.000000
# 1    NONCHALANT            NIFTY-ROOK  37.554515  49.908217   -29.000000
# 2    NONCHALANT    PREHISTORIC-PETREL  29.190866  60.491702  1552.426025
# 3    NONCHALANT  THERAPEUTIC-LIONFISH  13.253365  76.411056   867.591553
# 4          SOFT    ABORIGINAL-PICULET -68.632002  66.155301  1253.152832
#
#    FUEL_N2_MOL_PCT    FUEL_MW      FUEL_LHV  CO2_FUEL_RATIO
# 0         4.445063  16.572225  21514.222365        2.621803
# 1         1.053145  16.166097  21526.470829        2.714870
# 2        10.298848  17.273122  21494.438672        2.461189
# 3        13.188814  17.619149  21485.251979        2.381895
# 4         7.581916  16.947813  21503.417436        2.535736

# %%
engine_df = pd.read_csv('./data/engine_metadata-fad08922e295794745ba1cd70379140f.csv')
engine_df.head()
# Out:
#   CUSTOMER_NAME         PLANT_NAME ENGINE_ID     FILE_ID
# 0        SPIFFY  SPIRITUAL-POLECAT  ENGINE_1  data_1.csv
# 1        SPIFFY  SPIRITUAL-POLECAT  ENGINE_2  data_2.csv
# 2        SPIFFY  SPIRITUAL-POLECAT  ENGINE_3  data_3.csv
# 3    NONCHALANT         NIFTY-ROOK  ENGINE_1  data_4.csv
# 4    NONCHALANT         NIFTY-ROOK  ENGINE_2  data_5.csv

# %%
site_df['CUSTOMER_NAME'].nunique()
# Out:
# 15

# %%
engine_df['CUSTOMER_NAME'].unique()
# Out:
# array(['SPIFFY', 'NONCHALANT', 'SOFT', 'BUSY', 'FERVENT', 'GLEAMING',
#        'IDEALISTIC', 'DELIGHTFUL', 'TOUGH', 'TANGIBLE', 'DRAMATIC',
#        'KIND', 'JUDICIOUS', 'SCEPTICAL', 'MERCIFUL'], dtype=object)

# %%
import folium

map = folium.Map(location=[site_df['LATITUDE'].mean(), site_df['LONGITUDE'].mean()], zoom_start=1, control_scale=True)

# %%
for index, location_info in site_df.iterrows():
    folium.Marker([location_info["LATITUDE"], location_info["LONGITUDE"]],
                  popup=location_info["PLANT_NAME"]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import os

# %%
downloaded_data_list = os.listdir('data/all_data_v2/')

# %%
for file in downloaded_data_list:
    data_frame = pd.read_csv(f'data/all_data_v2/{file}')
    data_frame.fillna(0,inplace=True)

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# CMP_SPEED_1     0
# POWER_1         0
# FUEL_FLOW_1     0
# CO2_1           0
# CMP_SPEED_2     0
# POWER_2         0
# FUEL_FLOW_2     0
# CO2_2           0
# CMP_SPEED_3     0
# POWER_3         0
# FUEL_FLOW_3     0
# CO2_3           0
# CMP_SPEED_4     0
# POWER_4         0
# FUEL_FLOW_4     0
# CO2_4           0
# CMP_SPEED_5     0
# POWER_5         0
# FUEL_FLOW_5     0
# CO2_5           0
# CMP_SPEED_6     0
# POWER_6         0
# FUEL_FLOW_6     0
# CO2_6           0
# dtype: int64

# %%
downloaded_data_list_1 = os.listdir('data/New folder')

# %%
for file in downloaded_data_list_1:
    data_frame = pd.read_csv(f'data/New folder/{file}')
    data_frame.fillna(0,inplace=True)
    data_frame.to_csv(f'data/New folder/{file}',index=False)

# %%
df2=pd.read_csv("data/New folder/SILKY-WEASEL.csv")

# %%
df2.shape
# Out:
# (8761, 27)

# %%
df2.head()
# Out:
#    Unnamed: 0      Unnamed: 0.1  CMP_SPEED_1      POWER_1  FUEL_FLOW_1  \
# 0           0  01-01-2021 00:00  4758.466217  3718.441369     0.987648
# 1           1  01-01-2021 01:00  4761.778449  3718.012159     0.986664
# 2           2  01-01-2021 02:00  4766.026102  3729.037526     0.987223
# 3           3  01-01-2021 03:00  4764.875000  3735.181120     0.989217
# 4           4  01-01-2021 04:00  4758.684791  3724.973492     0.987618
#
#       CO2_1  CMP_SPEED_2  POWER_2  FUEL_FLOW_2  CO2_2  ...     CO2_4  \
# 0  2.346501          0.0      0.0          0.0    0.0  ...  2.290878
# 1  2.344162          0.0      0.0          0.0    0.0  ...  2.281823
# 2  2.345491          0.0      0.0          0.0    0.0  ...  2.279037
# 3  2.350229          0.0      0.0          0.0    0.0  ...  2.287661
# 4  2.346430          0.0      0.0          0.0    0.0  ...  2.286559
#
#    CMP_SPEED_5      POWER_5  FUEL_FLOW_5     CO2_5  CMP_SPEED_6      POWER_6  \
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# CMP_SPEED_1     0
# POWER_1         0
# FUEL_FLOW_1     0
# CO2_1           0
# CMP_SPEED_2     0
# POWER_2         0
# FUEL_FLOW_2     0
# CO2_2           0
# CMP_SPEED_3     0
# POWER_3         0
# FUEL_FLOW_3     0
# CO2_3           0
# CMP_SPEED_4     0
# POWER_4         0
# FUEL_FLOW_4     0
# CO2_4           0
# CMP_SPEED_5     0
# POWER_5         0
# FUEL_FLOW_5     0
# CO2_5           0
# CMP_SPEED_6     0
# POWER_6         0
# FUEL_FLOW_6     0
# CO2_6           0
# THERMAL_EFF     0
# dtype: int64

# %%
for file in downloaded_data_list_1:
    data_frame = pd.read_csv(f'data/New folder/{file}')
    # print(file)
    # print((data_frame.shape[1]-2)/4)
    for i in range(1,int((data_frame.shape[1]-2)/4)+1):
        for j in range(45):
            # print(str(file)[:-4])
            if site_df["PLANT_NAME"][j]== str(file)[:-4]:
                LHV=site_df["FUEL_LHV"][j]
                # print(LHV)
                data_frame["THERMAL_EFF"]=(data_frame["POWER_" +str(i)]/(data_frame["FUEL_FLOW_" +str(i)]*LHV))*100

  
    data_frame.to_csv(f'data/New folder/{file}',index=False)
