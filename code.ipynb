# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("data\site_metadata-7fc535965d0c074cea0be6786fc9518e.csv")

# %%
df
# Out:
#    CUSTOMER_NAME            PLANT_NAME   LATITUDE   LONGITUDE    ELEVATION  \
# 0         SPIFFY     SPIRITUAL-POLECAT  61.170356   42.874767   112.000000
# 1     NONCHALANT            NIFTY-ROOK  37.554515   49.908217   -29.000000
# 2     NONCHALANT    PREHISTORIC-PETREL  29.190866   60.491702  1552.426025
# 3     NONCHALANT  THERAPEUTIC-LIONFISH  13.253365   76.411056   867.591553
# 4           SOFT    ABORIGINAL-PICULET -68.632002   66.155301  1253.152832
# 5           SOFT      CARMINE-REINDEER -37.997369  178.144855   518.872375
# 6           SOFT       IDEALISTIC-DODO -31.151031  146.869226   200.000000
# 7           BUSY          ANCIENT-WASP -67.132885  140.038237  1049.166504
# 8           BUSY   AQUAMARINE-KANGAROO  -0.210084  -76.834778   283.042694
# 9           BUSY      RADIANT-STURGEON  61.773108  140.743140  1067.957153
# 10          BUSY         CURIOUS-QUAIL   5.142945   45.315171   355.958344
# ...

# %%
df.isnull().sum()
# Out:
# CUSTOMER_NAME      0
# PLANT_NAME         0
# LATITUDE           0
# LONGITUDE          0
# ELEVATION          0
# FUEL_N2_MOL_PCT    0
# FUEL_MW            0
# FUEL_LHV           0
# CO2_FUEL_RATIO     0
# dtype: int64

# %%
sns.boxplot(x=df["FUEL_LHV"])
# Out:
# <AxesSubplot:xlabel='FUEL_LHV'>

# %%
df1=pd.read_csv("data\engine_metadata-fad08922e295794745ba1cd70379140f.csv")

# %%
df1
# Out:
#     CUSTOMER_NAME         PLANT_NAME ENGINE_ID       FILE_ID
# 0          SPIFFY  SPIRITUAL-POLECAT  ENGINE_1    data_1.csv
# 1          SPIFFY  SPIRITUAL-POLECAT  ENGINE_2    data_2.csv
# 2          SPIFFY  SPIRITUAL-POLECAT  ENGINE_3    data_3.csv
# 3      NONCHALANT         NIFTY-ROOK  ENGINE_1    data_4.csv
# 4      NONCHALANT         NIFTY-ROOK  ENGINE_2    data_5.csv
# ..            ...                ...       ...           ...
# 208     SCEPTICAL    GIGANTIC-EARWIG  ENGINE_2  data_209.csv
# 209      MERCIFUL       PREMIUM-MOTH  ENGINE_1  data_210.csv
# 210      MERCIFUL       PREMIUM-MOTH  ENGINE_2  data_211.csv
# 211      MERCIFUL       PREMIUM-MOTH  ENGINE_3  data_212.csv
# 212      MERCIFUL       PREMIUM-MOTH  ENGINE_4  data_213.csv
#
# [213 rows x 4 columns]

# %%
df2=pd.read_csv("data/all_data_v2/data_1.csv")

# %%
df[""]
# Out:
#                Unnamed: 0    CMP_SPEED         POWER  FUEL_FLOW       CO2
# 0     2021-01-01 00:00:00  9086.266279  13905.170114   1.775834  4.655888
# 1     2021-01-01 01:00:00  9092.889629  13948.422258   1.777604  4.660529
# 2     2021-01-01 02:00:00  9083.496415  13915.430132   1.775123  4.654023
# 3     2021-01-01 03:00:00  9091.149440  13924.413251   1.776514  4.657670
# 4     2021-01-01 04:00:00  9098.178455  13951.961041   1.776658  4.658047
# ...                   ...          ...           ...        ...       ...
# 8756  2021-12-31 20:00:00  8069.214937  11316.082984   1.632899  4.281142
# 8757  2021-12-31 21:00:00  8052.326165  11282.339146   1.631990  4.278756
# 8758  2021-12-31 22:00:00     0.000000           NaN        NaN       NaN
# 8759  2021-12-31 23:00:00     0.000000           NaN        NaN       NaN
# 8760  2022-01-01 00:00:00     0.000000           NaN        NaN       NaN
#
# [8761 rows x 5 columns]

# %%
df2.shape
# Out:
# (8761, 5)
